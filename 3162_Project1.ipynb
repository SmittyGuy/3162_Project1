# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sb

# %%
teamstats_df = pd.read_csv("team_stats_2003_2023.csv")

# %%
teamstats_df
# Out:
#      year                  team  wins  losses  win_loss_perc  points  \
# 0    2003  New England Patriots    14       2          0.875     348
# 1    2003        Miami Dolphins    10       6          0.625     311
# 2    2003         Buffalo Bills     6      10          0.375     243
# 3    2003         New York Jets     6      10          0.375     283
# 4    2003      Baltimore Ravens    10       6          0.625     391
# ..    ...                   ...   ...     ...            ...     ...
# 667  2023     Carolina Panthers     2      15          0.118     236
# 668  2023   San Francisco 49ers    12       5          0.706     491
# 669  2023      Los Angeles Rams    10       7          0.588     404
# 670  2023      Seattle Seahawks     9       8          0.529     364
# 671  2023     Arizona Cardinals     4      13          0.235     330
#
#      points_opp  points_diff   mov   g  ...  rush_td  rush_yds_per_att  \
# ...

# %%
jetsStats_df = teamstats_df[teamstats_df['team'] == "New York Jets"]

# %%
sb.set_theme(rc={'figure.figsize':(10,10)})
sb.barplot(jetsStats_df, x="year", y="win_loss_perc")
# Out:
# <Axes: xlabel='year', ylabel='win_loss_perc'>

# %%
jetsStats_df[jetsStats_df['year'] == 2010]
# Out:
#      year           team  wins  losses  win_loss_perc  points  points_opp  \
# 225  2010  New York Jets    11       5          0.688     367         304
#
#      points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  penalties  \
# 225           63  3.9  16  ...       14               4.4      118        103
#
#      penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  ties
# 225            934      18       32.2          10.6      -122.93   NaN
#
# [1 rows x 35 columns]

# %%
teamstats_df[teamstats_df['year'] == 2010].describe()
# Out:
#          year       wins     losses  win_loss_perc      points  points_opp  \
# count    32.0  32.000000  32.000000      32.000000   32.000000   32.000000
# mean   2010.0   8.000000   8.000000       0.500156  352.593750  352.593750
# std       0.0   2.994619   2.994619       0.187196   64.326716   58.713003
# min    2010.0   2.000000   2.000000       0.125000  196.000000  232.000000
# 25%    2010.0   6.000000   6.000000       0.375000  304.250000  316.750000
# 50%    2010.0   7.500000   8.500000       0.469000  356.500000  346.500000
# 75%    2010.0  10.000000  10.000000       0.625000  391.000000  398.000000
# max    2010.0  14.000000  14.000000       0.875000  518.000000  471.000000
#
#        points_diff        mov     g  total_yards  ...    rush_td  \
# count    32.000000  32.000000  32.0    32.000000  ...  32.000000
# mean      0.000000  -0.009375  16.0  5376.218750  ...  12.468750
# std      96.980543   6.064618   0.0   561.394332  ...   3.801395
# ...

# %%
jetsStats_df[jetsStats_df['year'] == 2020]
# Out:
#      year           team  wins  losses  win_loss_perc  points  points_opp  \
# 547  2020  New York Jets     2      14          0.125     243         457
#
#      points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  penalties  \
# 547         -214  NaN  16  ...        9               4.1       94        101
#
#      penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  ties
# 547            952      29       26.3          10.9       -59.07   0.0
#
# [1 rows x 35 columns]

# %%
teamstats_df[teamstats_df['year'] == 2020].describe()
# Out:
#          year       wins     losses  win_loss_perc      points  points_opp  \
# count    32.0  32.000000  32.000000      32.000000   32.000000   32.000000
# mean   2020.0   7.968750   7.968750       0.500219  396.625000  396.625000
# std       0.0   3.496398   3.431208       0.216401   68.446235   58.675571
# min    2020.0   1.000000   2.000000       0.063000  243.000000  296.000000
# 25%    2020.0   5.000000   5.000000       0.313000  346.250000  356.500000
# 50%    2020.0   7.500000   8.500000       0.469000  395.500000  382.500000
# 75%    2020.0  11.000000  11.000000       0.688000  453.000000  440.750000
# max    2020.0  14.000000  15.000000       0.875000  509.000000  519.000000
#
#        points_diff  mov     g  total_yards  ...    rush_td  rush_yds_per_att  \
# count    32.000000  0.0  32.0    32.000000  ...  32.000000         32.000000
# mean      0.000000  NaN  16.0  5744.531250  ...  16.625000          4.384375
# ...

# %%
sb.barplot(jetsStats_df, x = 'year', y = 'yds_per_play_offense' )
# Out:
# <Axes: xlabel='year', ylabel='yds_per_play_offense'>

# %%
jetsStats_df['yds_per_play_offense'][jetsStats_df['year'] == 2010]
# Out:
# 225    5.2
# Name: yds_per_play_offense, dtype: float64

# %%
jetsStats_df['yds_per_play_offense'][jetsStats_df['year'] == 2015]
# Out:
# 385    5.5
# Name: yds_per_play_offense, dtype: float64

# %%
jetsStats_df['yds_per_play_offense'].describe()
# Out:
# count    21.000000
# mean      4.952381
# std       0.337074
# min       4.300000
# 25%       4.700000
# 50%       5.000000
# 75%       5.200000
# max       5.500000
# Name: yds_per_play_offense, dtype: float64

# %%
teamstats_df['yds_per_play_offense'][teamstats_df['year'] == 2010].describe()
# Out:
# count    32.000000
# mean      5.321875
# std       0.433094
# min       4.300000
# 25%       5.075000
# 50%       5.300000
# 75%       5.600000
# max       6.100000
# Name: yds_per_play_offense, dtype: float64

# %%
teamstats_df['yds_per_play_offense'][teamstats_df['year'] == 2015].describe()
# Out:
# count    32.000000
# mean      5.478125
# std       0.344294
# min       4.900000
# 25%       5.300000
# 50%       5.450000
# 75%       5.700000
# max       6.300000
# Name: yds_per_play_offense, dtype: float64

# %%
sb.barplot(jetsStats_df, x = 'year', y = 'points' )
# Out:
# <Axes: xlabel='year', ylabel='points'>

# %%
jetsStats_df['points'][jetsStats_df['year'] == 2010]
# Out:
# 225    367
# Name: points, dtype: int64

# %%
teamstats_df['points'][teamstats_df['year'] == 2010].describe()
# Out:
# count     32.000000
# mean     352.593750
# std       64.326716
# min      196.000000
# 25%      304.250000
# 50%      356.500000
# 75%      391.000000
# max      518.000000
# Name: points, dtype: float64

# %%
jetsStats_df['points'].describe()
# Out:
# count     21.000000
# mean     308.428571
# std       46.645012
# min      240.000000
# 25%      276.000000
# 50%      296.000000
# 75%      333.000000
# max      405.000000
# Name: points, dtype: float64

# %%
jetsStats_df['points'][jetsStats_df['year'] == 2008]
# Out:
# 162    405
# Name: points, dtype: int64

# %%
teamstats_df['points'][teamstats_df['year'] == 2008].describe()
# Out:
# count     32.000000
# mean     352.468750
# std       66.911586
# min      204.000000
# 25%      300.000000
# 50%      368.000000
# 75%      406.250000
# max      463.000000
# Name: points, dtype: float64

# %%
sb.barplot(jetsStats_df, x = 'year', y = 'points_opp' )
# Out:
# <Axes: xlabel='year', ylabel='points_opp'>

# %%
jetsStats_df['points_opp'][jetsStats_df['year'] == 2010]
# Out:
# 225    304
# Name: points_opp, dtype: int64

# %%
teamstats_df['points_opp'][teamstats_df['year'] == 2010].describe()
# Out:
# count     32.000000
# mean     352.593750
# std       58.713003
# min      232.000000
# 25%      316.750000
# 50%      346.500000
# 75%      398.000000
# max      471.000000
# Name: points_opp, dtype: float64

# %%
jetsStats_df['points_opp'].describe()
# Out:
# count     21.000000
# mean     358.285714
# std       64.255850
# min      236.000000
# 25%      314.000000
# 50%      356.000000
# 75%      387.000000
# max      504.000000
# Name: points_opp, dtype: float64
